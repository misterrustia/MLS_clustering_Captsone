# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/final_per_90_and_pAdj.csv')

# %%
df['int_tackl_recover'] = df['pAdj_def_interceptions']+df['pAdj_from_mish_tackles_won']+df['pAdj_Recoveries']

graph = df.loc[(df['int_tackl_recover']<35)&(df['Position']!='GK')&(df['Aerial_win_pct']<100)&
               (df['Aerial_win_pct']>0)&(df['Nineties']>5)]

print(len(graph))
sns.set_style('whitegrid')

fig, ax = plt.subplots()
fig.set_size_inches(18.5, 10.5)

# plt.gca().invert_xaxis()
# plt.xticks(rotation = 90)

x = graph['int_tackl_recover']
y = graph['Aerial_win_pct']
p = graph['player_name']

g = sns.scatterplot(data=graph, x =x, y=y ,hue='Position',
                ax=ax).set(title='MLS 2021 Aerial win pct Vs Interceptions tackles recoveries by position ')


for p, x, y in zip(p, x, y):
    if p == 'Walker Zimmerman':
        plt.annotate(p, (x, y))
    if y > 80:
         plt.annotate(p, (x, y))
    if x > 30:
        plt.annotate(p,(x,y))

    
plt.tight_layout()
# Out:
# 492

# %%
graph = df.loc[(df['int_tackl_recover']<35)&(df['Position']=='DF')&(df['Aerial_win_pct']<100)&
               (df['Aerial_win_pct']>0)&(df['Nineties']>10)]


sns.set_style('whitegrid')

fig, ax = plt.subplots()
fig.set_size_inches(18.5, 10.5)

# plt.gca().invert_xaxis()
# plt.xticks(rotation = 90)


g = sns.scatterplot(data=graph, x ='int_tackl_recover', y='Aerial_win_pct' ,hue='Squad_from_op',
                ax=ax).set(title='Defender Aerial win pct Vs Interceptions tackles recoveries')

x = graph['int_tackl_recover']
y = graph['Aerial_win_pct']
p = graph['player_name']


for p, x, y in zip(p, x, y):
    if p == 'Walker Zimmerman':
        plt.annotate(p, (x, y))
    if y > 72:
         plt.annotate(p, (x, y))
    if x > 24:
        plt.annotate(p,(x,y))

plt.tight_layout()

# %% [markdown]
# ## Walker Zimmerman is in the top of the graph but not the right of the graph of the graph showing he doesnt need to have a tone of interceptions tackles and recoveries to be at the best defender

# %%
graph.loc[(graph['int_tackl_recover']>20)&(graph['Aerial_win_pct']>60)][['player_name','Squad_from_op','int_tackl_recover','Total_Prg_Dist','carries_prog_dist',
                                 'Long_Cmp','Long_Cmp_pct',
                                 'Opposing_Poss','Opposing_Touches','Nineties']].sort_values('Long_Cmp',ascending=False)
# Out:
#         player_name Squad_from_op  int_tackl_recover  Total_Prg_Dist  \
# 59      Graham Zusi   Sporting KC          20.748695      376.567797
# 256    Carlos Terán  Chicago Fire          21.866479      458.518519
# 127   Andrew Gutman  NY Red Bulls          26.507952      303.431373
# 332    Emmanuel Más  Orlando City          21.183943      397.105263
# 60    Julian Araujo     LA Galaxy          21.848311      282.612903
# 269  Tommy Thompson      San Jose          22.854144      279.397590
#
#      carries_prog_dist   Long_Cmp  Long_Cmp_pct  Opposing_Poss  \
# 59          153.728814  11.398305          66.6           45.0
# 256          74.814815  10.462963          55.1           50.2
# 127         100.784314   6.519608          48.0           51.9
# 332         131.973684   4.210526          47.1           48.9
# 60          117.612903   4.161290          56.6           45.7
# 269         154.698795   3.253012          60.0           47.4
#
#      Opposing_Touches  Nineties
# 59         577.941176      23.6
# 256        592.823529      10.8
# 127        588.058824      20.4
# 332        577.647059       7.6
# 60         584.676471      31.0
# 269        548.264706       8.3

# %%
graph.loc[graph['Aerial_win_pct']>77][['player_name','Squad_from_op','int_tackl_recover','Total_Prg_Dist','carries_prog_dist',
                                 'Long_Cmp','Long_Cmp_pct',
                                 'Opposing_Poss','Opposing_Touches','Nineties']].sort_values('Long_Cmp',ascending=False)
# Out:
#               player_name    Squad_from_op  int_tackl_recover  Total_Prg_Dist  \
# 480         Brent Kallman    Minnesota Utd          20.175633      280.985915
# 456  Yeimar Gómez Andrade          Seattle          21.384702      285.202703
# 490         Maxime Chanot            NYCFC          20.569370      271.695502
# 485          Aljaž Struna      CF Montréal          14.153486      386.666667
# 409        Steve Birnbaum      D.C. United          18.036745      206.277778
# 253         Lucas Esteves  Colorado Rapids          17.844808      256.213592
#
#      carries_prog_dist  Long_Cmp  Long_Cmp_pct  Opposing_Poss  \
# 480          88.732394  8.380282          76.3           49.9
# 456          81.959459  7.567568          69.6           51.4
# 490         107.889273  6.262976          65.3           46.5
# 485          89.245283  5.974843          69.3           47.1
# 409          37.333333  5.500000          61.9           54.0
# 253         104.077670  3.398058          49.3           51.7
#
#      Opposing_Touches  Nineties
# 480        614.323529      14.2
# 456        628.764706      29.6
# 490        568.588235      28.9
# 485        582.117647      15.9
# 409        603.705882      18.0
# 253        609.352941      10.3

# %%
graph = df.loc[(df['Crosses']>.1)&(df['Position']=='DF')&(df['Aerial_win_pct']<100)&
               (df['Aerial_win_pct']>0)&(df['Nineties']>10)]

sns.set_style('whitegrid')

fig, ax = plt.subplots()
fig.set_size_inches(18.5, 10.5)

# plt.gca().invert_xaxis()
# plt.xticks(rotation = 90)


g = sns.scatterplot(data=graph, x='carries_prog',y ='Crosses',hue='Squad_from_op',
                ax=ax).set(title='Defender long ball completion Vs long competion pct')

x = graph['carries_prog']
y = graph['Crosses']
p = graph['player_name']

for p, x, y in zip(p, x, y):
    if p == 'Walker Zimmerman':
        plt.annotate(p, (x, y))
    if y > 4:
         plt.annotate(p, (x, y))
    if x > 5:
        plt.annotate(p,(x,y))
        
    
    

plt.tight_layout()

# %% [markdown]
# ## Walker is in the bottom left of this graph showing he does not carry or cross the ball in his role in the cener of the defense

# %%
graph.loc[(graph['Crosses']>3)&(graph['carries_prog']>5.5)][['player_name','Squad_from_op','Crosses','carries_prog','Total_Prg_Dist','carries_prog_dist',
                                 'Long_Cmp','Long_Cmp_pct',
                                 'Opposing_Poss','Opposing_Touches','Nineties']].sort_values('Long_Cmp',ascending=False)
# Out:
#          player_name   Squad_from_op   Crosses  carries_prog  Total_Prg_Dist  \
# 59       Graham Zusi     Sporting KC  3.093220      5.805085      376.567797
# 1     Julian Gressel     D.C. United  4.816054      5.719064      366.153846
# 34     Aaron Herrera  Real Salt Lake  3.476703      5.519713      363.189964
# 43   Romain Métanire   Minnesota Utd  3.239437      5.633803      393.978873
# 77              Ruan    Orlando City  3.157895      6.315789      221.913876
# 311     Andrew Brody  Real Salt Lake  3.333333      7.000000      205.500000
# 255    Jhon Espinoza    Chicago Fire  3.888889      6.111111      293.555556
#
#      carries_prog_dist   Long_Cmp  Long_Cmp_pct  Opposing_Poss  \
# 59          153.728814  11.398305          66.6           45.0
# 1           117.157191   7.424749          41.9           54.0
# 34          145.985663   7.383513          58.7           49.1
# 43          128.591549   6.478873          56.3           49.9
# 77          143.779904   3.732057          66.1           48.9
# 311         162.750000   3.333333          51.9           49.1
# 255         117.222222   2.777778          41.7           50.2
#
#      Opposing_Touches  Nineties
# 59         577.941176      23.6
# 1          603.705882      29.9
# 34         567.029412      27.9
# 43         614.323529      28.4
# 77         577.647059      20.9
# 311        567.029412      12.0
# 255        592.823529       9.0

# %%
graph = df.loc[(df['int_tackl_recover']<35)&(df['Position']=='DF')&(df['Aerial_win_pct']<100)&
               (df['Aerial_win_pct']>0)&(df['Nineties']>5)]

sns.set_style('whitegrid')

fig, ax = plt.subplots()
fig.set_size_inches(18.5, 10.5)

# plt.gca().invert_xaxis()
# plt.xticks(rotation = 90)


g = sns.scatterplot(data=graph, x ='Long_Cmp', y='Long_Cmp_pct',hue='Squad_from_op',
                ax=ax).set(title='Defender long ball completion Vs long competion pct')


x = graph['Long_Cmp']
y = graph['Long_Cmp_pct']
p = graph['player_name']
for p, x, y in zip(p, x, y):
    if p == 'Walker Zimmerman':
        plt.annotate(p, (x, y))
    elif y > 80:
         plt.annotate(p, (x, y))
    elif x > 12:
        plt.annotate(p,(x,y))
    
    
plt.tight_layout()

# %%
df.loc[df['Long_Cmp']>15][['player_name', 'Squad_from_op',
       'Long_Att','Long_Cmp','Long_Cmp_pct', 'Nation', 'Position', 'Nineties',
       'xA', 'Key_pass']]
# Out:
#        player_name Squad_from_op   Long_Att   Long_Cmp  Long_Cmp_pct  Nation  \
# 316  Andreu Fontàs   Sporting KC  19.787879  16.121212          81.5  es ESP
# 327   Ilie Sánchez   Sporting KC  22.007168  16.738351          76.1  es ESP
#
#     Position  Nineties        xA  Key_pass
# 316       DF      33.0  0.009091  0.242424
# 327       MF      27.9  0.010753  0.286738

# %% [markdown]
# ## walker is in the top half heading towards the right of the graph showing he is with the better players who are playing long balls

# %%
graph.loc[graph['Long_Cmp']>11.5][['player_name','Squad_from_op','Total_Prg_Dist','carries_prog_dist',
                                 'Long_Cmp','Long_Cmp_pct',
                                 'Opposing_Poss','Opposing_Touches','Nineties']].sort_values('Long_Cmp',ascending=False)
# Out:
#            player_name    Squad_from_op  Total_Prg_Dist  carries_prog_dist  \
# 316      Andreu Fontàs      Sporting KC      558.000000         246.757576
# 422       Danny Wilson  Colorado Rapids      441.286765         124.485294
# 415     Oswaldo Alanís         San Jose      334.537445         137.180617
# 412            Bressan        FC Dallas      438.144330         133.608247
# 627      Vito Wormgoor    Columbus Crew      405.594406          91.748252
# 443  Florian Jungwirth        Vancouver      278.264463         107.520661
# 444    Jonathan Mensah    Columbus Crew      357.695035          71.453901
# 481    Aboubacar Keita    Columbus Crew      335.188679          81.603774
#
#            player_name   Long_Cmp  Long_Cmp_pct  Opposing_Poss  \
# 316      Andreu Fontàs  16.121212          81.5           45.0
# 422       Danny Wilson  13.308824          72.4           51.7
# 415     Oswaldo Alanís  13.083700          79.2           47.4
# 412            Bressan  11.958763          75.8           48.9
# 627      Vito Wormgoor  11.958042          83.8           48.3
# 443  Florian Jungwirth  11.570248          82.8           53.9
# 444    Jonathan Mensah  11.524823          77.8           48.3
# 481    Aboubacar Keita  11.509434          75.8           48.3
#
#      Opposing_Touches  Nineties
# 316        577.941176      33.0
# 422        609.352941      27.2
# 415        548.264706      22.7
# 412        593.529412      19.4
# 627        568.823529      14.3
# 443        623.323529      12.1
# 444        568.823529      28.2
# 481        568.823529      10.6

# %%
graph = df.loc[(df['int_tackl_recover']<35)&(df['Position']=='DF')&(df['Aerial_win_pct']<100)&
               (df['Aerial_win_pct']>0)&(df['Nineties']>5)]
sns.set_style('whitegrid')

fig, ax = plt.subplots()
fig.set_size_inches(18.5, 10.5)

# plt.gca().invert_xaxis()
# plt.xticks(rotation = 90)


g = sns.scatterplot(data=graph, x ='Total_Prg_Dist', y='carries_prog_dist',
#                     hue='Squad_from_op',
                ax=ax).set(title='defender progressive carry distance Vs total progresive pass distance')

x = graph['Total_Prg_Dist']
y = graph['carries_prog_dist']
p = graph['player_name']
for p, x, y in zip(p, x, y):
    if p == 'Walker Zimmerman':
        plt.annotate(p, (x, y))
    elif y > 170:
         plt.annotate(p, (x, y))
    elif x > 450:
        plt.annotate(p,(x,y))
    
    
plt.tight_layout()

# %%
graph.loc[df['Total_Prg_Dist']>450][['player_name','Long_Cmp','Long_Cmp_pct','Total_Prg_Dist','carries_prog_dist',
                                  
                                  'Nineties']].sort_values('Total_Prg_Dist')
# Out:
#                    player_name   Long_Cmp  Long_Cmp_pct  Total_Prg_Dist  \
# 256               Carlos Terán  10.462963          55.1      458.518519
# 486  José Antonio Martínez Gil  10.898204          69.2      459.281437
# 310               Kamal Miller   6.818182          66.2      479.053030
# 411                Matt Besler  10.309278          83.3      508.041237
# 185              João Moutinho   7.083333          51.5      523.125000
# 316              Andreu Fontàs  16.121212          81.5      558.000000
#
#      carries_prog_dist  Nineties
# 256          74.814815      10.8
# 486         119.461078      16.7
# 310         171.666667      26.4
# 411         193.195876      19.4
# 185         150.347222      14.4
# 316         246.757576      33.0

# %%
'Key_pass',
       'Comp_prog', 'Total_Prg_Dist', 'dribble_Succ_pct', 'num_dribble_past', 'dribble_megs', 'carries',
       'carries_dist', 'carries_prog_dist'

# %%
df['Comp_prog'].describe()
# Out:
# count    705.000000
# mean       2.841329
# std        1.942034
# min        0.000000
# 25%        1.527778
# 50%        2.727273
# 75%        3.958333
# max       17.000000
# Name: Comp_prog, dtype: float64
